# %%
import matplotlib.pyplot as plt

# %%
L = [0.6916364079676965, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722, 0.6885902322727722]

# %%
plt.plot(L)
plt.ylabel('Loss')
plt.show()
